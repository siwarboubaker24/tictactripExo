# %%
import csv
import pandas as pd
import numpy as np

from pandas import DataFrame
from datetime import datetime,timedelta

# %%
data1 = pd.read_csv('./ticket_data.csv')

# %%
dat=data1.groupby(['o_station', 'd_station'])

# %%
data1
# Out:
#             id  company  o_station  d_station            departure_ts  \
# 0      6795025     8385        NaN        NaN  2017-10-13 14:00:00+00
# 1      6795026        9       63.0     1044.0  2017-10-13 13:05:00+00
# 2      6795027     8377     5905.0     6495.0  2017-10-13 13:27:00+00
# 3      6795028     8377     5905.0     6495.0  2017-10-13 13:27:00+00
# 4      6795029     8381     5905.0     6495.0  2017-10-13 21:46:00+00
# ...        ...      ...        ...        ...                     ...
# 74163  6869182       13      279.0    10729.0  2017-10-27 02:30:00+00
# 74164  6869185        9      279.0      304.0  2017-10-27 07:00:00+00
# 74165  6869187     8371    10642.0      304.0  2017-10-27 08:30:00+00
# 74166  6869189       13      279.0      304.0  2017-10-27 13:25:00+00
# 74167  6869191     8371    10642.0    10729.0  2017-10-27 14:45:00+00
#
#                    arrival_ts  price_in_cents                   search_ts  \
# ...

# %%
dat.max('price_in_cents')
# Out:
#                           id  company  price_in_cents  o_city  d_city
# o_station d_station
# 3.0       39.0       6848666       13            3480     628      37
#           61.0       6849450       13            4780     628     173
#           123.0      6862926       13            3600     628     144
#           132.0      6854174       13            2280     628     158
#           189.0      6854672       13            3680     628    5118
# ...                      ...      ...             ...     ...     ...
# 11012.0   11010.0    6844505     8387            9600     628     524
# 11013.0   11005.0    6835755     8387            5000     694     184
# 11014.0   11005.0    6835756     8387            5000     694     184
# 11015.0   11005.0    6835757     8387            5000     694     184
# 11017.0   10349.0    6795677     8387            5300   12166     857
#
# [2666 rows x 5 columns]

# %%
dat.min('price_in_cents')
# Out:
#                           id  company  price_in_cents  o_city  d_city
# o_station d_station
# 3.0       39.0       6840169        9            1200     628      37
#           61.0       6849450       13            4780     628     173
#           123.0      6862926       13            3600     628     144
#           132.0      6854165       13            1890     628     158
#           189.0      6854587       13            3680     628    5118
# ...                      ...      ...             ...     ...     ...
# 11012.0   11010.0    6844369     8387            9600     628     524
# 11013.0   11005.0    6835755     8387            5000     694     184
# 11014.0   11005.0    6835756     8387            5000     694     184
# 11015.0   11005.0    6835757     8387            5000     694     184
# 11017.0   10349.0    6795677     8387            5300   12166     857
#
# [2666 rows x 5 columns]

# %%
dat.mean('price_in_cents')
# Out:
#                                id      company  price_in_cents   o_city  \
# o_station d_station
# 3.0       39.0       6.841591e+06    12.333333     2238.333333    628.0
#           61.0       6.849450e+06    13.000000     4780.000000    628.0
#           123.0      6.862926e+06    13.000000     3600.000000    628.0
#           132.0      6.854169e+06    13.000000     2150.000000    628.0
#           189.0      6.854630e+06    13.000000     3680.000000    628.0
# ...                           ...          ...             ...      ...
# 11012.0   11010.0    6.844437e+06  8387.000000     9600.000000    628.0
# 11013.0   11005.0    6.835755e+06  8387.000000     5000.000000    694.0
# 11014.0   11005.0    6.835756e+06  8387.000000     5000.000000    694.0
# 11015.0   11005.0    6.835757e+06  8387.000000     5000.000000    694.0
# 11017.0   10349.0    6.795677e+06  8387.000000     5300.000000  12166.0
#
#                      d_city
# o_station d_station
# 3.0       39.0         37.0
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74168 entries, 0 to 74167
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               74168 non-null  int64
#  1   company          74168 non-null  int64
#  2   o_station        32727 non-null  float64
#  3   d_station        32727 non-null  float64
#  4   departure_ts     74168 non-null  object
#  5   arrival_ts       74168 non-null  object
#  6   price_in_cents   74168 non-null  int64
#  7   search_ts        74168 non-null  object
#  8   middle_stations  32727 non-null  object
#  9   other_companies  32727 non-null  object
#  10  o_city           74168 non-null  int64
#  11  d_city           74168 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 6.8+ MB

# %%
data1['departure_ts'] = data1['departure_ts'].apply(lambda _: datetime.strptime(_, "%Y-%m-%d %H:%M:%S+00"))

# %%
data1['arrival_ts'] = data1['arrival_ts'].apply(lambda _: datetime.strptime(_,"%Y-%m-%d %H:%M:%S+00"))

# %%
def duree():
    return (data1.arrival_ts - data1.departure_ts)

# %%
f=duree()

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74168 entries, 0 to 74167
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               74168 non-null  int64
#  1   company          74168 non-null  int64
#  2   o_station        32727 non-null  float64
#  3   d_station        32727 non-null  float64
#  4   departure_ts     74168 non-null  datetime64[ns]
#  5   arrival_ts       74168 non-null  datetime64[ns]
#  6   price_in_cents   74168 non-null  int64
#  7   search_ts        74168 non-null  object
#  8   middle_stations  32727 non-null  object
#  9   other_companies  32727 non-null  object
#  10  o_city           74168 non-null  int64
#  11  d_city           74168 non-null  int64
# dtypes: datetime64[ns](2), float64(2), int64(5), object(3)
# memory usage: 6.8+ MB

# %%
data1['duree'] = data1.arrival_ts - data1.departure_ts

# %%
data1.head()
# Out:
#         id  company  o_station  d_station        departure_ts  \
# 0  6795025     8385        NaN        NaN 2017-10-13 14:00:00
# 1  6795026        9       63.0     1044.0 2017-10-13 13:05:00
# 2  6795027     8377     5905.0     6495.0 2017-10-13 13:27:00
# 3  6795028     8377     5905.0     6495.0 2017-10-13 13:27:00
# 4  6795029     8381     5905.0     6495.0 2017-10-13 21:46:00
#
#            arrival_ts  price_in_cents                   search_ts  \
# 0 2017-10-13 20:10:00            4550  2017-10-01 00:13:31.327+00
# 1 2017-10-14 06:55:00            1450  2017-10-01 00:13:35.773+00
# 2 2017-10-14 21:24:00            7400  2017-10-01 00:13:40.212+00
# 3 2017-10-14 11:02:00           13500  2017-10-01 00:13:40.213+00
# 4 2017-10-14 19:32:00            7710  2017-10-01 00:13:40.213+00
#
#        middle_stations other_companies  o_city  d_city           duree
# 0                  NaN             NaN     611     542 0 days 06:10:00
# ...

# %%
dat1=data1.groupby(['o_station', 'd_station'])

# %%
dat1.max()
# Out:
#                           id  company        departure_ts          arrival_ts  \
# o_station d_station
# 3.0       39.0       6848666       13 2017-10-26 22:10:00 2017-10-27 04:25:00
#           61.0       6849450       13 2017-10-29 00:50:00 2017-10-29 20:05:00
#           123.0      6862926       13 2017-10-19 22:10:00 2017-10-20 20:40:00
#           132.0      6854174       13 2017-10-20 12:20:00 2017-10-20 21:35:00
#           189.0      6854672       13 2017-10-30 00:50:00 2017-10-30 15:25:00
# ...                      ...      ...                 ...                 ...
# 11012.0   11010.0    6844505     8387 2017-10-14 16:00:00 2017-10-15 18:45:00
# 11013.0   11005.0    6835755     8387 2017-10-14 17:00:00 2017-10-14 20:30:00
# 11014.0   11005.0    6835756     8387 2017-10-14 17:00:00 2017-10-14 20:30:00
# 11015.0   11005.0    6835757     8387 2017-10-14 17:00:00 2017-10-14 20:30:00
# 11017.0   10349.0    6795677     8387 2017-10-18 16:45:00 2017-10-19 14:40:00
#
# ...

# %%
dat1.min()
# Out:
#                           id  company        departure_ts          arrival_ts  \
# o_station d_station
# 3.0       39.0       6840169        9 2017-10-19 22:10:00 2017-10-20 04:25:00
#           61.0       6849450       13 2017-10-29 00:50:00 2017-10-29 20:05:00
#           123.0      6862926       13 2017-10-19 22:10:00 2017-10-20 20:40:00
#           132.0      6854165       13 2017-10-20 04:15:00 2017-10-20 09:15:00
#           189.0      6854587       13 2017-10-30 00:50:00 2017-10-30 15:25:00
# ...                      ...      ...                 ...                 ...
# 11012.0   11010.0    6844369     8387 2017-10-14 16:00:00 2017-10-15 18:45:00
# 11013.0   11005.0    6835755     8387 2017-10-14 17:00:00 2017-10-14 20:30:00
# 11014.0   11005.0    6835756     8387 2017-10-14 17:00:00 2017-10-14 20:30:00
# 11015.0   11005.0    6835757     8387 2017-10-14 17:00:00 2017-10-14 20:30:00
# 11017.0   10349.0    6795677     8387 2017-10-18 16:45:00 2017-10-19 14:40:00
#
# ...

# %%
dat1.mean()
# Out:
#                                id      company  price_in_cents   o_city  \
# o_station d_station
# 3.0       39.0       6.841591e+06    12.333333     2238.333333    628.0
#           61.0       6.849450e+06    13.000000     4780.000000    628.0
#           123.0      6.862926e+06    13.000000     3600.000000    628.0
#           132.0      6.854169e+06    13.000000     2150.000000    628.0
#           189.0      6.854630e+06    13.000000     3680.000000    628.0
# ...                           ...          ...             ...      ...
# 11012.0   11010.0    6.844437e+06  8387.000000     9600.000000    628.0
# 11013.0   11005.0    6.835755e+06  8387.000000     5000.000000    694.0
# 11014.0   11005.0    6.835756e+06  8387.000000     5000.000000    694.0
# 11015.0   11005.0    6.835757e+06  8387.000000     5000.000000    694.0
# 11017.0   10349.0    6.795677e+06  8387.000000     5300.000000  12166.0
#
#                      d_city
# o_station d_station
# 3.0       39.0         37.0
# ...

# %%
dat2 = pd.read_csv('./providers.csv')

# %%
dat2
# Out:
#        id  company_id provider_id           name        fullname has_wifi  \
# 0       9           1         NaN         ouibus          Ouibus     True
# 1      10           2         NaN        deinbus      Deinbus.de    False
# 2      11           3         NaN        infobus         Infobus    False
# 3      12           4         NaN  studentAgency  Student Agency    False
# 4      13           5         NaN        flixbus         Flixbus     True
# ..    ...         ...         ...            ...             ...      ...
# 222  8384          10          16         thalys          Thalys     True
# 223  8385          11         NaN            bbc       Blablacar    False
# 224  8387          30         NaN          vatry           Vatry      NaN
# 225  8388          40         NaN        beauval         Beauval      NaN
# 226  8389          12         NaN        idvroom         idVroom    False
#
#     has_plug has_adjustable_seats has_bicycle transport_type
# ...
